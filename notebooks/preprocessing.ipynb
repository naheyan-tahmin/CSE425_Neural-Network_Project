# %% [markdown]
# # MIDI Preprocessing Notebook
# Load MIDI files, tokenize note sequences, and inspect sequence statistics.

# %%
from src.config import TrainConfig
from src.training.common import load_sequences

cfg = TrainConfig()
data = load_sequences(cfg, genre='unknown')
data.shape
