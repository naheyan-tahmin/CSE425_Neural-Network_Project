# %% [markdown]
# # Markov Baseline Notebook
# Generate naive baseline compositions for assignment comparison.

# %%
from src.generation.generate_music import markov_baseline

samples = markov_baseline(seq_len=128, num_samples=3)
samples[0][:20]
